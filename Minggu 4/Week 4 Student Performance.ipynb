# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import datetime

x = datetime.datetime.now()

# %%
x
# Out:
# datetime.datetime(2024, 10, 25, 20, 31, 52, 794425)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.iloc[0:,6].dtype
# Out:
# dtype('int64')

# %%
scores = df["math score"]
print(scores)
scores.head()
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
scores.max()
# Out:
# 100

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
scores.head(10)
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# 5    71
# 6    88
# 7    40
# 8    64
# 9    38
# Name: math score, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
All_scores = df[["gender","reading score","math score","writing score"]]
All_scores
# Out:
#      gender  reading score  math score  writing score
# 0    female             72          72             74
# 1    female             90          69             88
# 2    female             95          90             93
# 3      male             57          47             44
# 4      male             78          76             75
# ..      ...            ...         ...            ...
# 995  female             99          88             95
# 996    male             55          62             55
# 997  female             71          59             65
# 998  female             78          68             77
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
All_scores.shape
# Out:
# (1000, 4)

# %%
math_passed = [df["math score"]>=50]
math_passed
# Out:
# [0       True
#  1       True
#  2       True
#  3      False
#  4       True
#         ...
#  995     True
#  996     True
#  997     True
#  998     True
#  999     True
#  Name: math score, Length: 1000, dtype: bool]

# %%
math_passed_genderwise = All_scores[All_scores["math score"]>=50]
math_passed_genderwise
# Out:
#      gender  reading score  math score  writing score
# 0    female             72          72             74
# 1    female             90          69             88
# 2    female             95          90             93
# 4      male             78          76             75
# 5    female             83          71             78
# ..      ...            ...         ...            ...
# 995  female             99          88             95
# 996    male             55          62             55
# 997  female             71          59             65
# 998  female             78          68             77
# 999  female             86          77             86
#
# [865 rows x 4 columns]

# %%
failed = df["math score"]<50
failed
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
#Students who passed(>=50) in writing score, actually completed the test preparation course
course_completed = df.loc[df["writing score"]>=50,"test preparation course"]
course_completed
course_completed
# Out:
# 0           none
# 1      completed
# 2           none
# 4           none
# 5           none
#          ...
# 995    completed
# 996         none
# 997    completed
# 998    completed
# 999         none
# Name: test preparation course, Length: 886, dtype: object

# %%
All_scores.plot()
# Out:
# <Axes: >

# %%
All_scores["math score"].plot()
# Out:
# <Axes: >

# %%
All_scores.plot.scatter(x="reading score",y="writing score",alpha=0.5)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
axs = df.plot.area(figsize=(20,16),subplots = True)

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(figsize=(20,16));

df.plot.area(ax=axs);

axs.set_ylabel("Scores for different Subjects");

# %% [markdown]
# **Image is saved in png format in output**

# %%
#Mean of math scores
df["math score"].mean()
# Out:
# 66.089

# %%
df["writing score"].mean()
# Out:
# 68.054

# %%
df["reading score"].mean()
# Out:
# 69.169

# %% [markdown]
# # Visualisasi
# Skor rata-rata dan plot menunjukkan bahwa siswa-siswa ini cenderung sedikit lebih baik dalam membaca dan menulis dibandingkan matematika

# %%
df[["math score","reading score","writing score"]].describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.agg({'math score': ['min','mean','max', 'median', 'skew'],
             'writing score': ['min', 'max', 'median', 'mean','skew']})
# Out:
#         math score  writing score
# min       0.000000      10.000000
# mean     66.089000      68.054000
# max     100.000000     100.000000
# median   66.000000      69.000000
# skew     -0.278935      -0.289444

# %%
#Average math score for male and female comparison
df[["gender","math score"]].groupby("gender").mean()
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %% [markdown]
# # Visualisasi
#
# Berdasarkan data, siswa laki-laki tampaknya lebih baik dalam matematika dibandingkan siswa perempuan

# %%
df[["test preparation course","math score","reading score","writing score"]].groupby("test preparation course").mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# # Visualiasi
# Orang yang telah menyelesaikan kursus persiapan ujian tampaknya memiliki nilai yang lebih baik dibandingkan orang yang tidak menyelesaikan kursus.

# %%
a = df[["race/ethnicity","math score","reading score","writing score"]].groupby("race/ethnicity").mean()
a
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %%
a.plot()
# Out:
# <Axes: xlabel='race/ethnicity'>

# %% [markdown]
# # Visualisasi
#
# Grup E tampaknya berkinerja lebih baik dibandingkan semua kelompok ras/etnis lainnya dalam semua kriteria kinerja

# %%
b = df[["parental level of education","math score","reading score","writing score"]].groupby("parental level of education").mean()
b
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
b.plot(figsize=(20,16))
# Out:
# <Axes: xlabel='parental level of education'>

# %% [markdown]
# # Visualisasi
# Tingkat pendidikan orang tua tampaknya mempunyai pengaruh terhadap prestasi siswa. Misalnya saja siswa yang orang tuanya bergelar magister menunjukkan kinerja yang lebih baik dibandingkan siswa lainnya.

# %%
c = df[["lunch","math score","reading score","writing score"]].groupby("lunch").mean()
c
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
c.plot()
# Out:
# <Axes: xlabel='lunch'>

# %% [markdown]
# # Visualisasi
# Mereka yang melakukan makan siang standar memiliki kinerja lebih baik dibandingkan siswa yang makan siang gratis atau dikurangi

# %%
df["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df["parental level of education"].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df["test preparation course"].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
df["lunch"].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
